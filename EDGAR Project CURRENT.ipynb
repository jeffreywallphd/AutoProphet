# %%
import requests
import requests_random_user_agent 
import pandas as pd
from bs4 import BeautifulSoup 
import re
import sqlite3
from sqlite3 import Error
import os
import sys
from contextlib import closing
import time
from dateutil import parser 
from datetime import datetime
from IPython.core.display import HTML
import ipywidgets as widgets
import json
import locale
locale.setlocale(locale.LC_ALL, '')
from sklearn.feature_extraction.text import CountVectorizer

# %%
# %%html
# <style>
# section {
#     border: solid black 1px;
#     margin: 5px 0px 5px 0px;
# }
# .sectionHeader {
#     background-color: black;
#     color: white;
#     font-size: 18px;
#     padding: 10px;
# }
# .sectionMain {
#     padding: 10px;
# }
# .sectionFooter {
#     background-color: #009933;
#     color: white;
#     font-size: to 16px;
#     padding: 10px;
#     border-top: solid black 1px;
# }
# .lightRow {
#     background-color: white;
#     padding: 10px;
#     margin: 0px;
# }
# .darkRow {
#     background-color: #EEEEEE;
#     padding: 10px;
#     margin: to 0px;
# }
#
# .lightRow:Hover {
#     background-color: #CC0000;
#     color: white;
# }
# .darkRow:Hover {
#     background-color: #CC0000;
#     color: white;
# }
#
# .successMessage {
#     background-color: #009933;
#     color: white;
#     padding: 10px;
# }
#
# .warningMessage {
#     background-color: #CC0000;
#     color: white;
#     padding: 10px;
# }
# </style>
# Out:
# <style>
# section {
#     border: solid black 1px;
#     margin: 5px 0px 5px 0px;
# }
# .sectionHeader {
#     background-color: black;
#     color: white;
#     font-size: 18px;
#     padding: 10px;
# }
# .sectionMain {
#     padding: 10px;
# }
# .sectionFooter {
#     background-color: #009933;
#     color: white;
#     font-size: to 16px;
#     padding: 10px;
#     border-top: solid black 1px;
# }
# .lightRow {
#     background-color: white;
#     padding: 10px;
#     margin: 0px;
# }
# .darkRow {
#     background-color: #EEEEEE;
#     padding: 10px;
#     margin: to 0px;
# }
#
# .lightRow:Hover {
#     background-color: #CC0000;
#     color: white;
# }
# .darkRow:Hover {
#     background-color: #CC0000;
#     color: white;
# }
#
# .successMessage {
#     background-color: #009933;
#     color: white;
#     padding: 10px;
# }
#
# .warningMessage {
#     background-color: #CC0000;
#     color: white;
#     padding: 10px;
# }
# </style>

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}
response = requests.get(f"https://data.sec.gov/submissions/CIK0000027419.json",headers = header)
data = None

if response.ok:
    data = json.loads(response.content)
    #print(data)
else:
    print(response.status_code)
    print(response.reason)

# %%
# Create a class to handle connection(s) to SQLite database(s).
class DB_Connection:

    # Initialize the object's attributes.
    def __init__(self, db_name, folder_path, db_path):
        self.db_name = db_name
        self.folder_path = folder_path

    # Create a directory for the DB file if the directory does not exist.
    def create_folder(self):
        if not os.path.exists(self.folder_path):
            os.makedirs(self.folder_path)
            print(f'Successfully created a new folder path {self.folder_path}.')
        else:
            print(f'Folder path {self.folder_path} already exists.')

    # Open connection to the database, if connection fails abort the program.
    # If the DB file does not already exist, it will be automatically created.
    @classmethod
    def open_conn(cls, db_path):
        try:
            cls.conn = sqlite3.connect(db_path)
            print(f'Successfully connected to the {db_path} database.')
            return cls.conn
        except sqlite3.Error as e:
            print(f'Error occurred, unable to connect to the {db_path} database.\\n{e}\nAbording program.')
            
            # sys.exit(0) means the program is exiting without any errors
            # sys.exit(1) means there was an error.
            sys.exit(1)
            
    # Close connection to the database.
    @classmethod
    def close_conn(cls):
        try:
            cls.conn.commit()
            print('Committed transactions.')
            cls.conn.close()
            print('Closing all database connections.')
        except Exception as e:
            print(f'Unable to close database connection.\n{e}')

# %% [markdown]
# Purpose:
# The DB_Connection class is designed to handle connections to SQLite databases. It includes methods to create a folder for the database file if it doesn't exist, open a connection to the database, and close the connection. This class facilitates database operations in a Python script.
#
# Class Attributes:
# db_name: A string representing the name of the database.
# folder_path: A string representing the path to the folder where the database file is stored.
#
# 1. Constructor (__init__ method):
#
# Parameters:
# db_name: The name of the database.
# folder_path: The path to the folder where the database file is stored.
# db_path: (Note: db_path is present in the parameter list, but not used in the method. If needed, you may want to use it to construct the full path to the database file.)
#
# Functionality:
# Initializes the object's attributes db_name and folder_path with the provided values.
#
# 2. create_folder method:
#
# Functionality:
# Checks if the specified folder path exists.
# If it doesn't exist, creates the folder.
# Prints a success message if a new folder is created; otherwise, indicates that the folder already exists.
#
# 3. open_conn method:
#
# Parameters: db_path: The path to the SQLite database file.
#
# Functionality:
# Attempts to establish a connection to the SQLite database specified by db_path.
# If successful, prints a success message and returns the connection object.
# If an error occurs during the connection attempt, prints an error message and aborts the program using sys.exit(1).
#
# 4. close_conn method:
#
# Functionality:
# Attempts to commit any outstanding transactions and close the database connection.
# Prints success messages for committing transactions and closing the connection.
# If an exception occurs during the process, prints an error message.

# %%
class Filing_Links:

    def __init__(self, company_CIKs, filing_types, start_date, end_date):
            self.company_CIKs = company_CIKs
            
            # Capitalize the letters of form type, since by default SQLite is case sensitive.
            self.filing_types = [item.upper() for item in filing_types]
            self.start_date = start_date
            self.end_date = end_date

    # Get available filings types for a specific company and their respective links.
    def Get_Filing_Links(self):
        try:
            for Company_CIK_Number in self.company_CIKs:
                for Filing_Type in self.filing_types:
                    
                    # define our parameters dictionary
                    filing_parameters = {'action':'getcompany',
                                  'CIK':Company_CIK_Number,
                                  'type':Filing_Type,
                                  'dateb':'',
                                  'owner':'exclude',
                                  'start':'',
                                  'output':'',
                                  'count':'100'}

                    # request the url, and then parse the response.
                    response = requests.get(url = r"https://www.sec.gov/cgi-bin/browse-edgar", params = filing_parameters)
                    
                    # Add 0.1 second time delay to comply with SEC.gov's 10 requests per second limit.
                    time.sleep(0.1)
                    soup = BeautifulSoup(response.content, 'html.parser')
                    
                    # Find the document table that contains filing information.
                    main_table = soup.find_all('table', class_='tableFile2')
                    
                    # The base URL will be used to construct document links URLs.
                    sec_base_url = r"https://www.sec.gov"
                    Company_Name_path=str(soup.find('span',{'class':'companyName'}))
                    if Company_Name_path != None:
                        try:
                            Company_Name = re.search('<span class="companyName">(.*)<acronym title', Company_Name_path).group(1)
                        except AttributeError:
                            print("Could not find company name, \assigning NULL value to company name.")
                            Company_Name = None
                            
                    # loop through each row of table and extract filing numbers, links, etc.
                    for row in main_table[0].find_all('tr'):
                        
                        # find all the rows under the 'td' element.
                        cols = row.find_all('td')
                        
                        # If no information was detected, move on to the next row.
                        if len(cols) != 0:
                            
                            # Get the text from the table.
                            Filing_Type = cols[0].text.strip()
                            Filing_Date = cols[3].text.strip()
                            Filing_Number = cols[4].text.strip()
                            Filing_Number = ''.join(e for e in Filing_Number if e.isalnum())

                            # Get the URL path to the filing number.
                            filing_number_path = cols[4].find('a')
                            if filing_number_path != None:
                                Filing_Number_Link = sec_base_url + filing_number_path['href']
                            else:
                               break

                            # Get the URL path to the document.
                            document_link_path = cols[1].find('a', {'href':True, 'id':'documentsbutton'})
                            if document_link_path != None:
                                Document_Link = sec_base_url + document_link_path['href']
                            else:
                                Document_Link = None

                            # Get the account number.
                            try:
                                Account_Number= cols[2].text.strip()
                                Account_Number = re.search('Acc-no:(.*)(34 Act)', Account_Number).group(1)
                                Account_Number = ''.join(e for e in Account_Number if e.isalnum())

                            except Exception as e:
                                """
                                Add break if you don't want empty account number rows.
                                If account number is not present, the interactive document
                                link will not be available. If the interactive link is not
                                present, we will not be able to extract the individual
                                tables containing financial statements..
                                """
                                Account_Number = None
                                print(f'Could not retrieve the account number, /assigning NULL value.\n{e}')

                            # Get the URL path to the interactive document.
                            interactive_data_path = cols[1].find('a', {'href':True, 'id':'interactiveDataBtn'})
                            if interactive_data_path != None:
                                Interactive_Data_Link = sec_base_url + interactive_data_path['href']
                                
                                # If the interactive data link exists, then so does the FilingSummary.xml link.
                                Summary_Link_Xml = Document_Link.replace(f"/{Account_Number}",'')\
                                                                .replace('-','')\
                                                                .replace('index.htm' ,'/FilingSummary.xml')

                            else:
                                # break
                                Interactive_Data_Link = None
                                Summary_Link_Xml = None

                            self.info_to_sql(Company_Name, Company_CIK_Number, Account_Number,
                                             Filing_Type, Filing_Number, Filing_Date, Document_Link,
                                             Interactive_Data_Link, Filing_Number_Link, Summary_Link_Xml)
        except Exception as e:
            print(f"Could not retrieve the table containing the necessary information.\
                    \nAbording the program.\nIf index list is out of range, make sure \
                    that you entered the correct CIK number(s).\n{e}")
            sys.exit(1)

    # Migrate the DataFrame containing, filing and document links information to a local SQLite database.
    def info_to_sql(self, Company_Name, Company_CIK_Number, Account_Number,Filing_Type, Filing_Number, Filing_Date, Document_Link,Interactive_Data_Link, Filing_Number_Link, Summary_Link_Xml):

        with DB_Connection.open_conn(db_path) as conn:
            try:
                with closing(conn.cursor()) as cursor:
                    cursor.execute(
                    """
                    CREATE TABLE IF NOT EXISTS filing_list (
                    filing_number integer PRIMARY KEY,
                    account_number integer,
                    company_name text NOT NULL,
                    cik integer NOT NULL,
                    filing_type text NOT NULL,
                    filing_date text NOT NULL,
                    document_link_html TEXT NOT NULL,
                    filing_number_link TEXT NOT NULL,
                    interactive_dash_link TEXT,
                    summary_link_xml TEXT
                    )
                    ;""")
            except ValueError as e:
                print(f"Error occurred while attempting to create filing_list table.\\nAbording the program.\n{e}")
                sys.exit(1)
            else:
                print("Successfully created the table.")
                print(f"Migrating information for filing number {Filing_Number} to the SQL table.......")
                try:
                    
                    # INSERT or IGNORE will insert a record if it does NOT duplicate an existing record.
                    with closing(conn.cursor()) as cursor:
                        cursor.execute(
                        """
                        INSERT or IGNORE INTO filing_list (
                        filing_number,
                        account_number,
                        company_name,
                        cik,
                        filing_type,
                        filing_date,
                        document_link_html,
                        filing_number_link,
                        interactive_dash_link,
                        summary_link_xml
                        ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?) """
                        ,(
                        Filing_Number,
                        Account_Number,
                        Company_Name,
                        Company_CIK_Number,
                        Filing_Type,
                        Filing_Date,
                        Document_Link,
                        Filing_Number_Link,
                        Interactive_Data_Link,
                        Summary_Link_Xml
                         ))
                except ValueError as e:
                    print(f"Error occurred while attempting to insert values into the filing_list table.\n{e}")

        DB_Connection.close_conn()

    # Extract individual table links to financial statements, supplementary data tables, etc
    def get_table_links(self):
        dfs = []
        with DB_Connection.open_conn(db_path) as conn:
            try:
                for Company_CIK_Number in self.company_CIKs:
                    for Filing_Type in self.filing_types:
                        df = pd.read_sql_query(
                             """
                             SELECT filing_number, summary_link_xml
                             FROM filing_list
                             WHERE summary_link_xml IS NOT NULL
                             AND filing_type = ?
                             AND cik = ?
                             AND filing_date BETWEEN ? AND ?
                             """, con = conn , params=(Filing_Type, Company_CIK_Number, self.start_date, self.end_date))
                        dfs.append(df)
                df_query2 = pd.concat(dfs)

            except ValueError as e:
                print(f"Error occurred while attempting to retrieve data from the filing_list table.\n{e}")
                sys.exit(1)

            # If the DataFrame is empty, terminate the program.
            if len(df_query2) == 0:
                print('DataFrame is empty, aborting the program.\nAbording the program.')
                sys.exit(1)
            try:
                with closing(conn.cursor()) as cursor:
                    cursor.execute(
                    """
                    CREATE TABLE IF NOT EXISTS individual_report_links (
                    filing_number integer,
                    short_name text,
                    report_url text,
                    FOREIGN KEY(filing_number) REFERENCES filing_list(filing_number),
                    UNIQUE(report_url)
                    )
                    ;""")
            except ValueError as e:
                print(f"Error occurred while attempting to create individual_report_links table.\\nAbording the program.\n{e}")
                sys.exit(1)

            # Extract the tables name and its respective URL
            # Currently, I do not have a function/method to extract data from a .XML file extension.
            for filing_number, summary_link_xml in df_query2.itertuples(index = False):
                response_2 = requests.get(summary_link_xml).content
                time.sleep(0.1)
                soup_2 = BeautifulSoup(response_2, 'lxml')
                for item in soup_2.find_all('report')[:-1]:
                    if item.shortname:
                        Short_Name = item.shortname.text
                        
                         # Remove special characters
                        Short_Name = re.sub(r"[^a-zA-Z0-9]+", ' ', Short_Name)
                        
                        # Remove white wite space at the end of the string.
                        Short_Name = Short_Name.rstrip()
                    else:
                        print('Short name could not be retrieved.')
                        Short_Name  = None
                        
                    # Some tables come only in the xml form.
                    if item.htmlfilename:
                        Report_Url = summary_link_xml.replace('FilingSummary.xml', item.htmlfilename.text)
                    elif item.xmlfilename:
                        Report_Url = summary_link_xml.replace('FilingSummary.xml', item.xmlfilename.text)
                    else:
                        print('URL to the individual report could not be retrieved.')
                        Report_Url = None
                    print(Short_Name)
                    print(Report_Url)
                    print(filing_number)
                    print('*'*50 + ' Inserting values into the table .... ' + '*'*50)
                    try:
                        with closing(conn.cursor()) as cursor:
                            cursor.execute(
                            """
                            INSERT OR IGNORE INTO individual_report_links (
                            filing_number,
                            short_name,
                            report_url
                            ) VALUES (?, ?, ?) """,(
                            filing_number,
                            Short_Name,
                            Report_Url
                             ))
                    except ValueError as e:
                        print(f"Error occurred while attempting to insert values into \the individual_report_links table.\nAbording the program.\n{e}")
                        sys.exit(1)

        DB_Connection.close_conn()

# %% [markdown]
# Purpose:
# The Filing_Links class is designed to fetch and store filing links for specified companies and filing types from the SEC website. It includes methods to retrieve filing information, migrate the data to a local SQLite database, and extract individual table links to financial statements.
#
# Class Attributes:
# company_CIKs: A list of Central Index Key (CIK) numbers representing companies.
# filing_types: A list of filing types.
# start_date: The start date for retrieving filing links.
# end_date: The end date for retrieving filing links.
#
# 1. Constructor (__init__ method):
#
# Parameters:
# company_CIKs: A list of CIK numbers for the companies.
# filing_types: A list of filing types.
# start_date: The start date for retrieving filing links.
# end_date: The end date for retrieving filing links.
#
# Functionality:
# Initializes the object's attributes company_CIKs, filing_types, start_date, and end_date with the provided values.
# Capitalizes the letters of filing types to ensure compatibility with SQLite's case sensitivity.
#
# 2. Get_Filing_Links method:
#
# Functionality:
# Retrieves filing links for specified companies and filing types from the SEC website.
# Parses the HTML response to extract filing information.
# Migrates the extracted information to a local SQLite database using the info_to_sql method.
#
# 3. info_to_sql method:
#
# Parameters:
# Various filing-related information (Company_Name, Company_CIK_Number, etc.).
#
# Functionality:
# Creates a connection to the SQLite database using the DB_Connection class.
# Creates a table (filing_list) if it does not already exist.
# Migrates filing information to the SQLite database.
#
# 4. get_table_links method:
#
# Functionality:
# Retrieves individual table links to financial statements from the SQLite database.
# Creates a table (individual_report_links) if it does not already exist.
# Extracts tables from the SEC website and inserts the relevant information into the individual_report_links table.

# %%
class Extract_Data:

    def __init__(self):
        self.df_xml = None
        
    # Extract table data from a .XMK
    def htm_table_extractor(self,report_url):
        
        # Note to self, .text is in Unicode, .content is in bytes.
        response_xml = requests.get(report_url).content
        time.sleep(0.1)
        soup_xml = BeautifulSoup(response_xml, "lxml")
        table = soup_xml.find_all('table')
        if table:
            try:
                print("Inserting table data into the DataFrame.")
                self.df_xml = pd.read_html(str(table))[0]
                self.df_xml = self.df_xml.replace({'\$':''}, regex = True)\
                                         .replace({'\)':''}, regex = True)\
                                         .replace({'\(':''}, regex = True)\
                                         .replace({'\%':''}, regex = True)\
                                         .replace({' ','', 1}, regex = True)

            except Exception as e:
                print(f'Error occurred while attempting to insert \table data into the DataFrame.\n{e}')
        else:
            print(f'No table detected for {report_url}.')

    # Retreive the necessary information information to extract data from the table's URL.
    def get_tables(self):

        dfs =[]
        with DB_Connection.open_conn(db_path) as conn:
            for company_CIK in filings1.company_CIKs:
                for filing_type in filings1.filing_types:
                    try:
                        df = pd.read_sql_query(
                            """
                            SELECT a.filing_number,
                                   a.company_name,
                                   a.filing_type,
                                   a.filing_date,
                                   b.short_name ,
                                   b.report_url
                            FROM filing_list a
                            INNER JOIN individual_report_links b
                            ON a.filing_number = b.filing_number
                            WHERE b.report_url LIKE '%.htm%'
                            AND a.cik = ?
                            AND a.filing_type = ?
                            AND a.filing_date BETWEEN ? AND ?
                            ORDER by filing_date DESC
                            LIMIT ?
                            """, con = conn , params=(company_CIK, filing_type, filings1.start_date, filings1.end_date , 10))
                        dfs.append(df)
                    except ValueError as e:
                        print(f"Error occurred while attempting to retreive data \
                                from the SQL database.\nAbording the program.\n{e}")
                        sys.exit(1)
            df_query1 = pd.concat(dfs)
            
            # If the DataFrame is empty, terminate the program.
            if len(df_query1) == 0:
                print('DataFrame is empty, aborting the program.\nAbording the program.')
                sys.exit(1)
            else:
                
                # If maximum recursion error occurs, increase recursion limit. sys.setrecursionlimit(25000)
                pass
            for filing_number,\
                company_name,\
                filing_type,\
                filing_date,\
                short_name,\
                report_url in df_query1.itertuples(index = False):
                print(f'Processing {short_name} table at {report_url}.')

                if report_url.endswith('.htm'):
                    try:
                        self.htm_table_extractor(report_url)
                    except ValueError as e:
                        print(f"Could not retreive the table for filing number \ {filing_number} at {report_url}\n{e}")
                        break
                    else:
                        try:
                            
                            # We want to name the table with a unique table name for easy reference.
                            table_name = filing_type + filing_date + '_' + \
                                         short_name.replace(' ','_') + '_' + str(filing_number)
                            
                            # Remove all special characters except for '_'
                            table_name = re.sub(r"[^a-zA-Z0-9]+", '_', table_name)
                            print(f'Inserting data from the DataFrame into SQL table {table_name}')
                            
                            # Check to see if table already exists in the database to avoid duplicate records.
                            with closing(conn.cursor()) as cursor:
                                cursor.execute(f""" SELECT count(name) FROM sqlite_master WHERE type='table' AND name= '{table_name}' """) # SQL injection vulnerability.
                                
                                # If count is 1, then table exists
                                if cursor.fetchone()[0]==1:
                                    print(f'Table {table_name} already exists.')
                                else:
                                    
                                    # Write records that are stored in the DataFrame into a SQL server database.
                                    self.df_xml.to_sql(con = conn, name=table_name, schema='SCHEMA', index=False, if_exists='fail')
                                    
                        except ValueError as e:
                            print(f"Could not migrate the {short_name} table to the SQL database.\n{e}")
                elif report_url.endswith('.xml'):
                    print('.xml extension link detected. Unable to to process the table.\\n.xml extension link support is expected to be developed in the future.')
                else:
                    print(f'Table for filing number {filing_number} could not be detected.')

        DB_Connection.close_conn()


    # Normalize the data.
    def transpose(self):

        db2_path = db_path.replace('.db','_transposed.db')
        with DB_Connection.open_conn(db_path) as conn:
            try:
                df_table_list = pd.read_sql_query(
                """
                SELECT name AS table_name
                FROM sqlite_master
                WHERE type='table'
                """, conn)
            except ValueError as e:
                print(f"Could not retrieve table list.\n{e}")
            for row in df_table_list.itertuples(index = False):
                try:
                    df_table = pd.read_sql_query(""" SELECT * FROM "{}" """.format(row.table_name), con=conn)
                except ValueError as e:
                    print(f"Could not read table {table_name}.\n{e}")
                else:
                    try:
                        while row.table_name not in ['filing_list', 'individual_report_links']:
                            
                            # Remove duplicate rows that have the same values.
                            df_table = df_table.drop_duplicates()
                            
                            # Transpose the pandas DataFrame.
                            df_table = df_table.T
                            
                            # Transform first rows into the header.
                            df_table.columns = df_table.iloc[0]
                            df_table = df_table[1:]
                            
                            # Remove special characters, replace empty spaces with _
                            df_table = df_table.rename(columns=lambda x: re.sub('\W+','_',str(x)))
                            df_table.columns = df_table.columns.str.strip('_')
                            df_table.columns = df_table.columns.str.lower()
                            
                            # Convert index of the DataFrame into a column.
                            df_table.reset_index(level=0, inplace=True)
                            
                            # Format the date column.
                            try:
                                date_list = []
                                for item in df_table.iloc[:,0]:
                                    match = re.search('\D{3}. \d{2}, \d{4}', item)
                                    if match is not None:
                                        
                                        # .strftime removes the time stamp.
                                        date= parser.parse(match.group()).strftime("%Y-%m-%d")
                                        date_list.append(date)
                                    else:
                                        date_list.append(item)
                                df_table.rename(columns={ df_table.columns[0]: "date" }, inplace = True)
                                df_table['date'] = date_list
                                print('Successfully formatted the date.')
                            except Exception as e:
                                df_table.rename(columns={ df_table.columns[0]: "name" }, inplace = True)
                                print(e)

                            # Convert rows to numeric data types such as integers and floats.
                            df_table.replace(',','', regex=True, inplace=True)
                            df_table = df_table.apply(pd.to_numeric, errors = 'ignore')
                            
                            # Dynamically rename duplicate rows that have the same name.
                            if any(df_table.columns.duplicated()):
                                print('Duplicate column name detected.\nRenaming the duplicate column name.  ')
                                columns_series = pd.Series(df_table.columns)
                                for dup in columns_series[columns_series.duplicated()].unique():
                                    columns_series[columns_series[columns_series == dup].index.values.tolist()] = \
                                    [dup + '.' + str(i) if i != 0 else dup for i in range(sum(columns_series == dup))]
                                df_table.columns = columns_series
                            break
                    except Exception as e:
                        print(f"Could not transpose the table.\n{e}")
                    else:
                        with DB_Connection.open_conn(db2_path) as conn2:
                            
                            # Check to see if table already exists in the database.
                            with closing(conn2.cursor()) as cursor:
                                cursor.execute(f""" SELECT count(name) FROM sqlite_master WHERE type='table' AND name= '{row.table_name}' """) # SQL injection vulnerability.
                                # If count is 1, then table exists
                                
                                if cursor.fetchone()[0]==1 and row.table_name not in ['filing_list', 'individual_report_links']:
                                    print(f'Table {row.table_name} already exists.')
                                else:
                                    try:
                                        print(f'Connected to the {db2_path} database.')
                                        print(f'Inserting data from the DataFrame into SQL table {row.table_name}')
                                        
                                        # Write records that are stored in the DataFrame into a SQL server database.
                                        df_table.to_sql(con = conn2, name = row.table_name, schema ='SCHEMA', if_exists = 'replace', index = False)

                                    except Exception as e:
                                        print(f"Could not migrate the {row.table_name} table to the normalized SQL database.\n{e}")
        DB_Connection.close_conn()

# %% [markdown]
# Purpose:
# The Extract_Data class is designed to extract table data from URLs provided in the individual_report_links table, normalize the data, and store it in a new SQLite database.
#
# Class Attributes:
# df_xml: A DataFrame to store XML table data.
#
# 1. Constructor (__init__ method):
#
# Functionality:
# Initializes the object's attribute df_xml as None.
#
# 2. htm_table_extractor method:
#
# Parameters:
# report_url: URL of the HTML table.
#
# Functionality:
# Extracts table data from an HTML report URL.
# Normalizes the data and stores it in the df_xml DataFrame.
#
# 3. get_tables method:
#
# Functionality:
# Retrieves necessary information from the SQLite database.
# Processes table URLs, extracts data using htm_table_extractor, and migrates it to a new SQLite database.
# Creates a table (individual_report_links) if it does not already exist.
#
# 4. transpose method:
#
# Functionality:
# Transposes tables in the original SQLite database, normalizes the data, and stores it in a new SQLite database (db2_path).
# Handles duplicate column names and converts rows to numeric data types.

# %%
# You can find company's CIK number at https://www.sec.gov/edgar/searchedgar/companysearch.html
company_CIKs = ['27419']
# Enter what forms(s) you want to extract using the '10-K', '10-Q', '8-K' format.
filing_types = ['10-q']
# Enter the database name that you want to use and populate.
# The database will be automatically created if it does not exist.
db_name = 'edgar.db'
# Specify the folder path for DB file. For example "C:\sqlite\db"
folder_path = r"C:\sqlite\db"
db_path = f"{folder_path}\{db_name}"
# Enter the date range for the filings in the 'YYYY-MM-DD' format
start_date = '2022-01-01'
end_date = '2022-12-29'

# %% [markdown]
# Purpose:
# The provided configuration settings are intended for extracting and storing SEC filing information related to specific companies and filing types. The configuration is designed for obtaining buy reports from the SEC database.
#
# Configuration Settings:
#
# 1. company_CIKs:
# Description: A list of Central Index Key (CIK) numbers representing companies for which buy reports will be extracted.
# Usage: You need to replace the existing CIK number with the CIK number of the specific company you are interested in. You can find CIK numbers on the SEC EDGAR Company Search page.
#
# 2. filing_types:
# Description: A list of filing types that you want to extract. Use the '10-K', '10-Q', '8-K' format.
# Usage: Modify the list to include the specific filing types relevant to buy reports. For example, '10-q' is provided as an initial value, but you can add other relevant types such as '10-K'.
#
# 3. db_name:
# Description: The name of the SQLite database that will be used to store the extracted filing information.
# Usage: Change the value to the desired name for your database. The script will automatically create the database if it does not exist.
#
# 4. folder_path:
# Description: The folder path where the SQLite database file will be stored.
# Usage: Provide the appropriate folder path where you want the SQLite database file ('edgar.db') to be saved. Ensure that you have write permissions for the specified folder.
#
# 5. db_path:
# Description: The full path to the SQLite database file, combining folder_path and db_name.
# Usage: The script generates this path automatically based on folder_path and db_name. You don't need to modify this directly unless you want to specify a custom path.
#
# 6. start_date and end_date:
# Description: The date range for the filings in the 'YYYY-MM-DD' format.
# Usage: Set the appropriate start and end dates to filter filings within the specified date range. Adjust these dates based on your requirements.
#
# Important Note:
# Before running the script, ensure that the specified folder path (folder_path) exists, and you have the necessary write permissions to create the SQLite database file in that location.
#
# Modify the provided configuration settings according to your specific requirements for extracting buy reports from the SEC database.

# %%
connection1 = DB_Connection(db_name, folder_path, db_path)
connection1.create_folder()
filings1 = Filing_Links(company_CIKs, filing_types, start_date, end_date)
filings1.Get_Filing_Links()
filings1.get_table_links()
data1 = Extract_Data()
data1.get_tables()
data1.transpose()
# Out:
# Folder path C:\sqlite\db already exists.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049231431784 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049231204578 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604923965103 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049221414240 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049221202524 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604922974429 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049211446311 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049211218572 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604921978092 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049201348663 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049201146473 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604920927451 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049191255634 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049191068875 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604919870292 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049181203294 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049181038858 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604918864055 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049171213709 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049171042907 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604917860211 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049162014874 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049161848763 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049161674134 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049151254856 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049151073101 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604915895078 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049141251983 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049141066834 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604914875310 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049131246167 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049131064679 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604913992344 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604913880794 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049121220029 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049121051639 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604912863333 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049111225176 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049111055444 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604911873752 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049101229984 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049101042423 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604910864810 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049091223125 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049091042389 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604909875691 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049081232459 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049081048610 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604908874859 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049071277902 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049071094320 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604907893016 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049061250281 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049061071316 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604906883135 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049051241006 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049051066257 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604905876447 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049041184292 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049041016633 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604904842950 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049031043815 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604903890345 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604903731992 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604902853573 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604902763509 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604902677431 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 001060491812875 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 001060491736311 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 001060491661553 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049783930 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049718795 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 00106049652355 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604999772810 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604999708992 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604999644615 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604998767936 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604998707870 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604998646301 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604997737622 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604997679761 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604997625409 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604996680242 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604996629518 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604996581029 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604995600272 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604995572190 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604995546275 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604994564044 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604994548518 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Could not retrieve the account number, /assigning NULL value.
# 'NoneType' object has no attribute 'group'
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully created the table.
# Migrating information for filing number 0010604994533803 to the SQL table.......
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# C:\Users\daron\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# Cover Page
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R1.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Operations
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R2.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Comprehensive Income
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R3.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Financial Position
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R4.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Financial Position Parenthetical
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R5.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Cash Flows
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R6.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Shareholders Investment
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R7.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Shareholders Investment Parenthetical
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R8.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Accounting Policies
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R9.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Dermstore Sale
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R10.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Revenues
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R11.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Fair Value Measurements
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R12.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Property and Equipment
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R13.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Commercial Paper and Long Term Debt
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R14.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R15.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Share Repurchase
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R16.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Pension Benefits
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R17.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Accumulated Other Comprehensive Income Loss
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R18.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Accounting Policies Policies
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R19.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Revenues Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R20.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Fair Value Measurements Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R21.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R22.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Share Repurchase Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R23.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Pension Benefits Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R24.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Accumulated Other Comprehensive Income Loss Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R25.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Dermstore Sale Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R26.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Revenues Disaggregation of Revenue Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R27.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Revenues Narrative Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R28.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Revenues Gift Card Liability Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R29.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Fair Value Measurements Schedule of Fair Value Measurements Recurring Basis Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R30.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Fair Value Measurements Schedule of Significant Financial Instruments not Measured at Fair Value Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R31.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Property and Equipment Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R32.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Commercial Paper and Long Term Debt Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R33.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments Narrative Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R34.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments Effect of Hedges on Debt Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R35.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments Effect of Hedges on Net Interest Expense Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R36.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Share Repurchase Schedule of Activity Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R37.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Share Repurchase Narrative Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R38.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Pension Benefits Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R39.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Accumulated Other Comprehensive Income Loss Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000015/R40.htm
# 10604922974429
# ************************************************** Inserting values into the table .... **************************************************
# Cover Page
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R1.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Operations
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R2.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Comprehensive Income
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R3.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Financial Position
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R4.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Financial Position Parenthetical
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R5.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Cash Flows
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R6.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Shareholders Investment
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R7.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Shareholders Investment Parenthetical
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R8.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Accounting Policies
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R9.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Dermstore Sale
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R10.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Revenues
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R11.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Fair Value Measurements
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R12.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Property and Equipment
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R13.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Commercial Paper and Long Term Debt
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R14.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R15.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Income Taxes
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R16.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Share Repurchase
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R17.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Pension Benefits
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R18.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Accumulated Other Comprehensive Income Loss
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R19.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Accounting Policies Policies
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R20.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Revenues Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R21.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Fair Value Measurements Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R22.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R23.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Share Repurchase Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R24.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Pension Benefits Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R25.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Accumulated Other Comprehensive Income Loss Tables
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R26.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Dermstore Sale Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R27.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Revenues Disaggregation of Revenue Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R28.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Revenues Narrative Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R29.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Revenues Gift Card Liability Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R30.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Fair Value Measurements Schedule of Fair Value Measurements Recurring Basis Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R31.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Fair Value Measurements Schedule of Significant Financial Instruments not Measured at Fair Value Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R32.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Property and Equipment Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R33.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Commercial Paper and Long Term Debt Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R34.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments Narrative Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R35.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments Effect of Hedges on Debt Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R36.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Derivative Financial Instruments Effect of Hedges on Net Interest Expense Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R37.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Income Taxes Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R38.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Share Repurchase Schedule of Activity Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R39.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Pension Benefits Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R40.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Accumulated Other Comprehensive Income Loss Details
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000027/R41.htm
# 106049221202524
# ************************************************** Inserting values into the table .... **************************************************
# Cover Page
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000037/R1.htm
# 106049221414240
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Operations
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000037/R2.htm
# 106049221414240
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Comprehensive Income
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000037/R3.htm
# 106049221414240
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Financial Position
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000037/R4.htm
# 106049221414240
# ************************************************** Inserting values into the table .... **************************************************
# Consolidated Statements of Financial Position Parenthetical
# https://www.sec.gov/Archives/edgar/data/27419/000002741922000037/R5.htm
# 106049221414240
# ...
# Inserting data from the DataFrame into SQL table 10_Q2022_11_23_Accounting_Policies_106049221414240
# Table 10_Q2022_11_23_Accounting_Policies_106049221414240 already exists.
# Processing Dermstore Sale table at https://www.sec.gov/Archives/edgar/data/27419/000002741922000037/R10.htm.
# Inserting table data into the DataFrame.
# Inserting data from the DataFrame into SQL table 10_Q2022_11_23_Dermstore_Sale_106049221414240
# Table 10_Q2022_11_23_Dermstore_Sale_106049221414240 already exists.
# Committed transactions.
# Closing all database connections.
# Successfully connected to the C:\sqlite\db\edgar.db database.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Connected to the C:\sqlite\db\edgar_transposed.db database.
# Inserting data from the DataFrame into SQL table filing_list
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Connected to the C:\sqlite\db\edgar_transposed.db database.
# Inserting data from the DataFrame into SQL table individual_report_links
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Cover_Page_2251321583589 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Consolidated_Statements_of_Cash_Flows_2251321583589 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Consolidated_Statements_Of_Operations_2251321583589 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Consolidated_Statements_of_Comprehensive_Income_2251321583589 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Consolidated_Statements_of_Comprehensive_Income_Parenthetical_2251321583589 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Consolidated_Balance_Sheets_2251321583589 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Consolidated_Balance_Sheets_Parenthetical_2251321583589 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Consolidated_Statements_of_Stockholders_Equity_2251321583589 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Description_of_Business_Accounting_Policies_and_Supplemental_Disclosures_2251321583589 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_03_Financial_Instruments_2251321583589 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Document_and_Entity_Information_13475621598537 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Consolidated_Balance_Sheets_13475621598537 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Consolidated_Balance_Sheets_Parenthetical_13475621598537 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Consolidated_Statements_of_Operations_13475621598537 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Consolidated_Statements_of_Operations_Parenthetical_13475621598537 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Consolidated_Statements_of_Comprehensive_Income_Loss_13475621598537 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Consolidated_Statements_of_Redeemable_Noncontrolling_Interest_and_Stockholders_Equity_13475621598537 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Consolidated_Statements_of_Redeemable_Noncontrolling_Interest_and_Stockholders_Equity_Parenthetical_13475621598537 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Consolidated_Statements_of_Cash_Flows_13475621598537 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_02_08_Overview_13475621598537 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_Document_and_Entity_Information_137845211127769 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_INCOME_STATEMENTS_137845211127769 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_COMPREHENSIVE_INCOME_STATEMENTS_137845211127769 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_BALANCE_SHEETS_137845211127769 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_BALANCE_SHEETS_Parenthetical_137845211127769 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_CASH_FLOWS_STATEMENTS_137845211127769 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_STOCKHOLDERS_EQUITY_STATEMENTS_137845211127769 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_ACCOUNTING_POLICIES_137845211127769 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_EARNINGS_PER_SHARE_137845211127769 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_07_29_OTHER_INCOME_EXPENSE_NET_137845211127769 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Cover_Page_10604921729320 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Consolidated_Statements_of_Operations_10604921729320 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Consolidated_Statements_of_Comprehensive_Income_10604921729320 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Consolidated_Statements_of_Financial_Position_10604921729320 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Consolidated_Statements_of_Financial_Position_Parenthetical_10604921729320 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Consolidated_Statements_of_Cash_Flows_10604921729320 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Consolidated_Statements_of_Shareholders_Investment_10604921729320 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Consolidated_Statements_of_Shareholders_Investment_Parenthetical_10604921729320 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Summary_of_Accounting_Policies_10604921729320 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2021_03_10_Coronavirus_COVID_19_10604921729320 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Cover_Page_10604922725853 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Audit_Information_10604922725853 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Consolidated_Statements_of_Operations_10604922725853 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Consolidated_Statements_of_Comprehensive_Income_10604922725853 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Consolidated_Statements_of_Financial_Position_10604922725853 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Consolidated_Statements_of_Financial_Position_Parenthetical_10604922725853 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Consolidated_Statements_of_Cash_Flows_10604922725853 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Consolidated_Statements_of_Shareholders_Investment_10604922725853 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Consolidated_Statements_of_Shareholders_Investment_Parenthetical_10604922725853 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_03_09_Summary_of_Accounting_Policies_10604922725853 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_Document_and_Entity_Information_137845221115247 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_INCOME_STATEMENTS_137845221115247 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_COMPREHENSIVE_INCOME_STATEMENTS_137845221115247 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_BALANCE_SHEETS_137845221115247 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_BALANCE_SHEETS_Parenthetical_137845221115247 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_CASH_FLOWS_STATEMENTS_137845221115247 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_STOCKHOLDERS_EQUITY_STATEMENTS_137845221115247 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_ACCOUNTING_POLICIES_137845221115247 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_EARNINGS_PER_SHARE_137845221115247 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_K2022_07_28_OTHER_INCOME_EXPENSE_NET_137845221115247 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Cover_Page_106049221414240 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Consolidated_Statements_of_Operations_106049221414240 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Consolidated_Statements_of_Comprehensive_Income_106049221414240 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Consolidated_Statements_of_Financial_Position_106049221414240 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Consolidated_Statements_of_Financial_Position_Parenthetical_106049221414240 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Consolidated_Statements_of_Cash_Flows_106049221414240 already exists.
# Successfully formatted the date.
# Duplicate column name detected.
# Renaming the duplicate column name.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Consolidated_Statements_of_Shareholders_Investment_106049221414240 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Consolidated_Statements_of_Shareholders_Investment_Parenthetical_106049221414240 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Accounting_Policies_106049221414240 already exists.
# Successfully formatted the date.
# Successfully connected to the C:\sqlite\db\edgar_transposed.db database.
# Table 10_Q2022_11_23_Dermstore_Sale_106049221414240 already exists.
# Committed transactions.
# Closing all database connections.
